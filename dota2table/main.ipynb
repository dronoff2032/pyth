# %% [markdown]
# Цель работы: Научится работать с библиотекой pandas, анализировать данные и работать с таблицами в python

# %% [markdown]
# Импортируем библиотеку и читаем нашу таблицу

# %%
import pandas as pd

table = pd.read_csv("Dota2 Heroes by MMR Bracket.csv", encoding="ISO-8859-1")

# %% [markdown]
# читаем первые n строк

# %%
table.head()
# Out:
#            Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 0       Anti-Mage                11.16%               51.22%
# 1             Axe                17.36%               52.93%
# 2            Bane                 2.31%               47.96%
# 3     Bloodseeker                 4.71%               48.53%
# 4  Crystal Maiden                13.83%               50.54%
#
#   (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 0                   9.65%                 51.53%                   7.91%
# 1                  16.18%                 51.01%                  14.50%
# 2                   2.38%                 49.05%                   2.71%
# 3                   3.28%                 48.43%                   2.77%
# 4                  10.69%                 48.85%                   8.37%
#
#   (3K-4K MMR) WinRate(%) (4K-5K MMR) PickRate(%) (4K-5K MMR) WinRate(%)  \
# 0                 51.77%                   6.48%                 51.03%
# ...

# %% [markdown]
# читаем последние n строк

# %%
table.tail()
# Out:
#            Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 119          Mars                 2.40%               43.91%
# 120   Dawnbreaker                 6.88%               48.19%
# 121         Marci                 3.70%               47.74%
# 122  Primal Beast                 6.40%               49.02%
# 123        Muerta                12.27%               51.92%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 119                   2.93%                 44.23%                   3.20%
# 120                   8.54%                 47.69%                   9.86%
# 121                   3.75%                 48.74%                   4.19%
# 122                   7.89%                 49.31%                   9.62%
# 123                  14.74%                 51.18%                  17.28%
#
#     (3K-4K MMR) WinRate(%) (4K-5K MMR) PickRate(%) (4K-5K MMR) WinRate(%)  \
# ...

# %% [markdown]
# информация о таблице

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Heroes                   124 non-null    object
#  1   (<2K MMR) PickRate(%)    124 non-null    object
#  2   (<2K MMR) WinRate(%)     124 non-null    object
#  3   (2K-3K MMR) PickRate(%)  124 non-null    object
#  4   (2K-3K MMR) WinRate(%)   124 non-null    object
#  5   (3K-4K MMR) PickRate(%)  124 non-null    object
#  6   (3K-4K MMR) WinRate(%)   124 non-null    object
#  7   (4K-5K MMR) PickRate(%)  124 non-null    object
#  8   (4K-5K MMR) WinRate(%)   124 non-null    object
#  9   (>5K MMR) PickRate(%)    124 non-null    object
#  10  (>5K MMR) WinRate(%)     124 non-null    object
#  11  Heroes.1                 124 non-null    object
#  12  (>2K MMR) KDA Ratio      124 non-null    float64
#  13  (>2K MMR) Avg Match      124 non-null    object
# ...

# %% [markdown]
# все столбцы в колонке

# %%
table.columns
# Out:
# Index(['Heroes', '(<2K MMR) PickRate(%)', '(<2K MMR) WinRate(%)',
#        '(2K-3K MMR) PickRate(%)', '(2K-3K MMR) WinRate(%)',
#        '(3K-4K MMR) PickRate(%)', '(3K-4K MMR) WinRate(%)',
#        '(4K-5K MMR) PickRate(%)', '(4K-5K MMR) WinRate(%)',
#        '(>5K MMR) PickRate(%)', '(>5K MMR) WinRate(%)', 'Heroes.1',
#        '(>2K MMR) KDA Ratio', '(>2K MMR) Avg Match', '(2K-3K MMR) KDA Ratio',
#        '(2K-3K) Avg Match', '(3K-4K MMR) KDA Ratio', '(3K-4K MMR) Avg Match',
#        '(4K-5K MMR) KDA Ratio', '(4K-5K MMR) Avg Match', '(<5K MMR) KDA Ratio',
#        '(<5K MMR) Avg Match'],
#       dtype='object')

# %% [markdown]
# в numpy

# %%
table.to_numpy()
# Out:
# array([['Anti-Mage', '11.16%', '51.22%', ..., '39:01', 3.45, '37:18'],
#        ['Axe', '17.36%', '52.93%', ..., '39:45', 2.56, '37:42'],
#        ['Bane', '2.31%', '47.96%', ..., '39:37', 2.29, '36:48'],
#        ...,
#        ['Marci', '3.70%', '47.74%', ..., '37:55', 2.49, '35:37'],
#        ['Primal Beast', '6.40%', '49.02%', ..., '39:38', 3.4, '36:59'],
#        ['Muerta', '12.27%', '51.92%', ..., '40:13', 2.93, '37:39']],
#       dtype=object)

# %% [markdown]
# Статические значения (минимум, максимум, середина и так далее)

# %%
table.describe()
# Out:
#        (>2K MMR) KDA Ratio  (2K-3K MMR) KDA Ratio  (3K-4K MMR) KDA Ratio  \
# count           124.000000             124.000000             124.000000
# mean              2.723790               2.880161               2.939839
# std               0.408277               0.474124               0.504660
# min               1.990000               2.010000               2.030000
# 25%               2.470000               2.560000               2.590000
# 50%               2.675000               2.785000               2.870000
# 75%               2.960000               3.152500               3.240000
# max               4.460000               4.730000               4.860000
#
#        (4K-5K MMR) KDA Ratio  (<5K MMR) KDA Ratio
# count             124.000000           124.000000
# mean                2.969758             2.983629
# std                 0.526736             0.560948
# min                 2.010000             1.980000
# 25%                 2.597500             2.582500
# ...

# %% [markdown]
# колличество уникальных значений

# %%
table.nunique()
# Out:
# Heroes                     124
# (<2K MMR) PickRate(%)      117
# (<2K MMR) WinRate(%)       116
# (2K-3K MMR) PickRate(%)    123
# (2K-3K MMR) WinRate(%)     116
# (3K-4K MMR) PickRate(%)    123
# (3K-4K MMR) WinRate(%)     117
# (4K-5K MMR) PickRate(%)    121
# (4K-5K MMR) WinRate(%)     117
# (>5K MMR) PickRate(%)      118
# (>5K MMR) WinRate(%)       115
# Heroes.1                   124
# (>2K MMR) KDA Ratio         78
# (>2K MMR) Avg Match         86
# (2K-3K MMR) KDA Ratio       82
# (2K-3K) Avg Match           90
# (3K-4K MMR) KDA Ratio       84
# (3K-4K MMR) Avg Match       89
# (4K-5K MMR) KDA Ratio       94
# (4K-5K MMR) Avg Match       90
# (<5K MMR) KDA Ratio         90
# (<5K MMR) Avg Match         98
# dtype: int64

# %% [markdown]
# получаем уникальные значения

# %%
table['Heroes'].unique()
# Out:
# array(['Anti-Mage', 'Axe', 'Bane', 'Bloodseeker', 'Crystal Maiden',
#        'Drow Ranger', 'Earthshaker', 'Juggernaut', 'Mirana', 'Morphling',
#        'Shadow Fiend', 'Phantom Lancer', 'Puck', 'Pudge', 'Razor',
#        'Sand King', 'Storm Spirit', 'Sven', 'Tiny', 'Vengeful Spirit',
#        'Windranger', 'Zeus', 'Kunkka', 'Lina', 'Lion', 'Shadow Shaman',
#        'Slardar', 'Tidehunter', 'Witch Doctor', 'Lich', 'Riki', 'Enigma',
#        'Tinker', 'Sniper', 'Necrophos', 'Warlock', 'Beastmaster',
#        'Queen of Pain', 'Venomancer', 'Faceless Void', 'Wraith King',
#        'Death Prophet', 'Phantom Assassin', 'Pugna', 'Templar Assassin',
#        'Viper', 'Luna', 'Dragon Knight', 'Dazzle', 'Clockwerk', 'Leshrac',
#        "Nature's Prophet", 'Lifestealer', 'Dark Seer', 'Clinkz',
#        'Omniknight', 'Enchantress', 'Huskar', 'Night Stalker',
#        'Broodmother', 'Bounty Hunter', 'Weaver', 'Jakiro', 'Batrider',
# ...

# %% [markdown]
# выбрасываем дубликаты из таблицы

# %%
table.drop_duplicates()
# Out:
#              Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 0         Anti-Mage                11.16%               51.22%
# 1               Axe                17.36%               52.93%
# 2              Bane                 2.31%               47.96%
# 3       Bloodseeker                 4.71%               48.53%
# 4    Crystal Maiden                13.83%               50.54%
# ..              ...                   ...                  ...
# 119            Mars                 2.40%               43.91%
# 120     Dawnbreaker                 6.88%               48.19%
# 121           Marci                 3.70%               47.74%
# 122    Primal Beast                 6.40%               49.02%
# 123          Muerta                12.27%               51.92%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 0                     9.65%                 51.53%                   7.91%
# ...

# %% [markdown]
# сортриуем таблицу

# %%
table.sort_values(by="(>2K MMR) KDA Ratio")
# Out:
#             Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 59     Broodmother                 1.12%               43.17%
# 24            Lion                19.47%               45.70%
# 25   Shadow Shaman                14.78%               51.99%
# 31          Enigma                 4.07%               46.75%
# 103        Techies                 7.04%               47.41%
# ..             ...                   ...                  ...
# 92          Medusa                 2.56%               48.08%
# 32          Tinker                 7.65%               49.78%
# 40     Wraith King                14.24%               56.65%
# 21            Zeus                10.88%               53.32%
# 65         Spectre                15.72%               56.49%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 59                    0.86%                 47.07%                   0.86%
# ...

# %% [markdown]
# выводим имена героев

# %%
table['Heroes']
# Out:
# 0           Anti-Mage
# 1                 Axe
# 2                Bane
# 3         Bloodseeker
# 4      Crystal Maiden
#             ...
# 119              Mars
# 120       Dawnbreaker
# 121             Marci
# 122      Primal Beast
# 123            Muerta
# Name: Heroes, Length: 124, dtype: object

# %% [markdown]
# выводим только те данные, которые соответствуют условию

# %%
table[table['(>2K MMR) KDA Ratio'] < 5]
# Out:
#              Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 0         Anti-Mage                11.16%               51.22%
# 1               Axe                17.36%               52.93%
# 2              Bane                 2.31%               47.96%
# 3       Bloodseeker                 4.71%               48.53%
# 4    Crystal Maiden                13.83%               50.54%
# ..              ...                   ...                  ...
# 119            Mars                 2.40%               43.91%
# 120     Dawnbreaker                 6.88%               48.19%
# 121           Marci                 3.70%               47.74%
# 122    Primal Beast                 6.40%               49.02%
# 123          Muerta                12.27%               51.92%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 0                     9.65%                 51.53%                   7.91%
# ...

# %% [markdown]
# выводим кортеж, содержащий количество строк и столбцов

# %%
table.shape
# Out:
# (124, 22)

# %% [markdown]
# удаляем данные из колонки (>2k MMR) KDA Ration

# %%
table.drop(columns=["(>2K MMR) KDA Ratio"])
# Out:
#              Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 0         Anti-Mage                11.16%               51.22%
# 1               Axe                17.36%               52.93%
# 2              Bane                 2.31%               47.96%
# 3       Bloodseeker                 4.71%               48.53%
# 4    Crystal Maiden                13.83%               50.54%
# ..              ...                   ...                  ...
# 119            Mars                 2.40%               43.91%
# 120     Dawnbreaker                 6.88%               48.19%
# 121           Marci                 3.70%               47.74%
# 122    Primal Beast                 6.40%               49.02%
# 123          Muerta                12.27%               51.92%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 0                     9.65%                 51.53%                   7.91%
# ...

# %% [markdown]
# количество пропущенных значений в прцоентах

# %%
table.isnull().mean() * 100
# Out:
# Heroes                     0.0
# (<2K MMR) PickRate(%)      0.0
# (<2K MMR) WinRate(%)       0.0
# (2K-3K MMR) PickRate(%)    0.0
# (2K-3K MMR) WinRate(%)     0.0
# (3K-4K MMR) PickRate(%)    0.0
# (3K-4K MMR) WinRate(%)     0.0
# (4K-5K MMR) PickRate(%)    0.0
# (4K-5K MMR) WinRate(%)     0.0
# (>5K MMR) PickRate(%)      0.0
# (>5K MMR) WinRate(%)       0.0
# Heroes.1                   0.0
# (>2K MMR) KDA Ratio        0.0
# (>2K MMR) Avg Match        0.0
# (2K-3K MMR) KDA Ratio      0.0
# (2K-3K) Avg Match          0.0
# (3K-4K MMR) KDA Ratio      0.0
# (3K-4K MMR) Avg Match      0.0
# (4K-5K MMR) KDA Ratio      0.0
# (4K-5K MMR) Avg Match      0.0
# (<5K MMR) KDA Ratio        0.0
# (<5K MMR) Avg Match        0.0
# dtype: float64

# %% [markdown]
# Меняем данные в таблице

# %%
table = table.replace("48.97%", "47.87%")

# %% [markdown]
# Выводим определенные столбцы и значения

# %%
table.loc[[1, 2],["Heroes", "Heroes.1"]]
# Out:
#   Heroes Heroes.1
# 1    Axe      Axe
# 2   Bane     Bane

# %% [markdown]
# Получаем список

# %%
table.values.tolist()
# Out:
# [['Anti-Mage',
#   '11.16%',
#   '51.22%',
#   '9.65%',
#   '51.53%',
#   '7.91%',
#   '51.77%',
#   '6.48%',
#   '51.03%',
#   '4.45%',
#   '50.24%',
#   'Anti-Mage',
#   3.21,
#   '41:30',
#   3.4,
#   '40:56',
#   3.42,
#   '40:04',
#   3.41,
#   '39:01',
#   3.45,
#   '37:18'],
#  ['Axe',
#   '17.36%',
#   '52.93%',
#   '16.18%',
#   '51.01%',
#   '14.50%',
#   '49.92%',
#   '13.20%',
#   '49.10%',
#   '10.88%',
#   '48.68%',
#   'Axe',
#   2.57,
#   '42:22',
#   2.56,
#   '41:46',
#   2.56,
#   '40:55',
#   2.57,
#   '39:45',
#   2.56,
#   '37:42'],
#  ['Bane',
#   '2.31%',
#   '47.96%',
#   '2.38%',
#   '49.05%',
#   '2.71%',
#   '50.76%',
#   '3.19%',
#   '50.41%',
#   '4.88%',
#   '51.95%',
#   'Bane',
#   2.35,
#   '41:51',
#   2.43,
#   '41:27',
#   2.43,
#   '40:36',
#   2.39,
#   '39:37',
#   2.29,
#   '36:48'],
#  ['Bloodseeker',
#   '4.71%',
#   '48.53%',
#   '3.28%',
#   '48.43%',
#   '2.77%',
#   '47.87%',
#   '2.57%',
#   '48.77%',
#   '2.44%',
#   '49.23%',
# ...

# %% [markdown]
# Сохраняем все в csv файл

# %%
table.to_csv("DOTA222 COOL.csv", index=False)

# %% [markdown]
# Вывод: я научился работать с библиотекой pandas и таблицами в python, а также научился анализорвать данные.
